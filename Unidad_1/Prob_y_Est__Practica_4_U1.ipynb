# %% [markdown]
# <a href="https://colab.research.google.com/github/24041182-sys/Probabilidad-y-estadistica/blob/main/Unidad_1/Prob_y_Est__Practica_4_U1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y Estadistica
# ## Unidad 1
# ## Practica 4: Diagrama de Cajas y bigotes.
# Docente: Jose Gabriel Rodriguez Rivas
#
# Alumno: Oliver Giovani Hernandez Nevarez **24041182**

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1 = []
for i in range(100):
  numero_aleatorio = round( random.uniform(50,100), 2 )
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [64.65, 64.8, 87.96, 58.56, 51.74, 71.02, 77.58, 90.93, 69.05, 61.08, 61.52, 67.45, 80.77, 76.25, 96.46, 88.14, 90.71, 95.05, 83.29, 54.03, 71.96, 70.3, 59.01, 58.18, 98.32, 53.73, 65.35, 79.12, 67.36, 88.12, 52.17, 95.37, 78.16, 96.02, 61.13, 57.98, 84.47, 92.38, 79.55, 58.82, 67.88, 62.8, 89.06, 53.68, 71.8, 78.13, 62.91, 83.89, 74.79, 84.64, 64.59, 92.02, 61.13, 60.28, 58.52, 50.37, 51.32, 71.27, 78.24, 54.36, 57.23, 70.17, 53.45, 96.05, 97.85, 91.63, 86.1, 52.19, 74.1, 69.31, 89.25, 91.18, 93.94, 87.47, 82.84, 62.73, 75.26, 66.13, 99.38, 78.62, 95.02, 84.38, 96.95, 99.58, 82.84, 51.42, 53.02, 66.74, 96.91, 57.07, 60.47, 69.2, 78.77, 99.7, 69.28, 93.61, 75.69, 53.62, 96.79, 91.0]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio2 = round( random.uniform(70,100), 2 )
  fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [81.79, 75.15, 83.07, 89.32, 99.68, 96.61, 87.65, 96.54, 81.84, 94.7, 98.4, 83.11, 73.02, 78.95, 95.44, 75.83, 85.31, 73.25, 74.44, 73.56, 99.4, 93.66, 89.17, 73.08, 77.83, 84.44, 78.2, 99.12, 87.72, 79.72, 96.41, 91.24, 99.24, 85.9, 89.58, 83.2, 70.46, 95.97, 90.33, 86.25, 84.14, 78.85, 79.47, 87.21, 75.9, 70.37, 87.63, 70.13, 83.6, 75.63, 72.97, 82.16, 92.51, 90.5, 81.4, 89.01, 87.54, 89.36, 79.96, 86.09, 71.55, 93.98, 78.7, 80.54, 73.42, 82.51, 88.8, 78.45, 90.77, 78.45, 97.57, 79.4, 85.33, 79.69, 78.76, 90.17, 93.49, 76.98, 73.45, 79.55, 72.18, 92.28, 95.2, 88.42, 99.83, 80.25, 79.01, 94.83, 90.84, 96.38, 86.49, 85.36, 98.85, 86.57, 93.25, 79.69, 99.02, 76.38, 81.21, 79.1]

# %%
plt.boxplot(fabrica1,)
plt.ylabel('Edades')
plt.title('Produccion de Fabrica 1')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(fabrica1, vert=True, patch_artist=True)
ax1.set_title('produccion fabrica 1')

bplot2 = ax2.boxplot(fabrica2, vert=True, patch_artist=True)
ax2.set_title('produccion fabrica 2')
plt.show()

# %%
fabrica1.append(150)
print(fabrica1)
# Out:
# [64.65, 64.8, 87.96, 58.56, 51.74, 71.02, 77.58, 90.93, 69.05, 61.08, 61.52, 67.45, 80.77, 76.25, 96.46, 88.14, 90.71, 95.05, 83.29, 54.03, 71.96, 70.3, 59.01, 58.18, 98.32, 53.73, 65.35, 79.12, 67.36, 88.12, 52.17, 95.37, 78.16, 96.02, 61.13, 57.98, 84.47, 92.38, 79.55, 58.82, 67.88, 62.8, 89.06, 53.68, 71.8, 78.13, 62.91, 83.89, 74.79, 84.64, 64.59, 92.02, 61.13, 60.28, 58.52, 50.37, 51.32, 71.27, 78.24, 54.36, 57.23, 70.17, 53.45, 96.05, 97.85, 91.63, 86.1, 52.19, 74.1, 69.31, 89.25, 91.18, 93.94, 87.47, 82.84, 62.73, 75.26, 66.13, 99.38, 78.62, 95.02, 84.38, 96.95, 99.58, 82.84, 51.42, 53.02, 66.74, 96.91, 57.07, 60.47, 69.2, 78.77, 99.7, 69.28, 93.61, 75.69, 53.62, 96.79, 91.0, 150]

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(fabrica1, vert=True, patch_artist=True)
ax1.set_title('produccion fabrica 1')

bplot2 = ax2.boxplot(fabrica2, vert=True, patch_artist=True)
ax2.set_title('produccion fabrica 2')
plt.show()
